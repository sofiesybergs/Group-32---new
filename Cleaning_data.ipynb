# %% [markdown]
# # Code for the Exam project

# %% [markdown]
# Importing packages

# %%
import requests
import time
import tqdm
import pandas as pd
import os
import json
import openpyxl 
from pathlib import Path
from zipfile import ZipFile
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import NaN
import seaborn as sns
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from matplotlib.patches import Circle
from tabulate import tabulate

# %% [markdown]
# Importing the CSV file into the notebook

# %%
fp_data = Path.cwd() / "data" 
Path.mkdir(fp_data, exist_ok=True)  
print(fp_data)
# Out:
# /Users/sofiesyberg/Desktop/KU/2. Semester/data science/project/data

# %%
file_path= fp_data / 'combined_data.csv'
df = pd.read_csv(file_path)

# %%
#rename columns
df.columns= ['type and adress', 'price', 'date and type', 'm2 and kr/m2', 'rooms', 'year built', 'difference', 'idk']

# %% [markdown]
# Starting the cleaning process of our data and getting rid of values that we don't need in the data set

# %%
df['address'] = df['type and adress'].apply(lambda x: x.split("EEjerlejlighed", 1)[-1].strip())
df.drop('type and adress', axis=1, inplace=True) 
df['date']=df['date and type'].apply(lambda x: x.split("Alm.", 1)[0].strip())
df.drop('date and type', axis=1, inplace=True) 

df['kr/m2']=df['m2 and kr/m2'].apply(lambda x: x.split('m²', 1)[-1].strip())
df['kr/m2']= df['kr/m2'].str[:-5]

df['m2']=df['m2 and kr/m2'].apply(lambda x: x.split('m²', 1)[0].strip())

df['price']= df['price'].str[:-3]
df['price'] = df['price'].apply(lambda x: int(re.sub(r'\D', '', x)))
df['price']=df['price'].astype(int)

df['datetime'] = pd.to_datetime(df['date'], format = '%d-%m-%Y')
df['year']= df['datetime'].dt.year
df['quarter']=df['datetime'].dt.quarter

df['year + quarter'] = df['year'].astype(str) + 'K' + df['quarter'].astype(str)

df.drop('difference', axis=1, inplace=True)
df.drop('idk', axis=1, inplace=True) 
df.drop('year', axis=1, inplace=True)
df.drop('quarter', axis=1, inplace=True)
#df.drop('month', axis=1, inplace=True) 
df.drop('m2 and kr/m2', axis=1, inplace=True)

pattern = r'\b\d{4}\b'
df['postal_code'] = df['address'].apply(lambda x: re.search(pattern, x).group() if re.search(pattern, x) else None)

# %%
df['kr/m2'] = df['kr/m2'].astype(str).apply(lambda x: int(re.sub(r'\D', '', x)))
df['kr/m2']=df['kr/m2'].astype(int)

# %% [markdown]
# Checking if there are any missing values in the data set

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# price             0
# rooms             0
# year built        0
# address           0
# date              0
# kr/m2             0
# m2                0
# datetime          0
# year + quarter    0
# postal_code       0
# dtype: int64

# %%
df_1 = df.sort_values(by='price', ascending=True)
df_1.to_csv('sorted_df.csv', index=False)

# %% [markdown]
# Constructing a scatterplot of the apartment prices over time

# %%
plt.figure(figsize=(10, 6))
ax = plt.gca()
plt.scatter(df_1['datetime'], df_1['price'], marker='o', alpha=0.7)
plt.ylabel('kr.')
ax.grid(True, alpha=0.5)
plt.xticks(rotation=45, ha='right')
# Show the plot
plt.tight_layout()
plt.show()
plt.savefig('df_1.png', dpi=300)

# %% [markdown]
# Plotting the apartment the sqm prices over time

# %%
plt.figure(figsize=(10, 6))
ax = plt.gca()
plt.scatter(df_1['datetime'], df_1['kr/m2'], marker='o', alpha=0.7)
plt.ylabel('kr/m2')
ax.grid(True, alpha=0.5)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Since the scatterplot shows outliers clustering together, we are removing these

# %%
#Removing outliers where the sqm price is over 100000, and where more than one apartment is sold on the same specific date
cleaned_data_set = df[df['kr/m2'] > 1000000].groupby(['datetime', 'price']).size().reset_index(name='count')
cleaned_data_set = cleaned_data_set[cleaned_data_set['count'] > 1]

merged_data = pd.merge(df, cleaned_data_set, on=['datetime', 'price'], how='left', indicator=True)

filtered_data_to_remove = merged_data[merged_data['_merge'] == 'left_only']

filtered_data_to_remove.drop('_merge', axis=1, inplace=True)

df_2=filtered_data_to_remove.drop(columns='count')
# Out:
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/96134484.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data_to_remove.drop('_merge', axis=1, inplace=True)

# %% [markdown]
# Since the scatterplot still shows some outliers, there are removed as well

# %%
plt.figure(figsize=(10, 6))
ax = plt.gca()
plt.scatter(df_2['datetime'], df_2['kr/m2'], marker='o', alpha=0.7)
plt.ylabel('kr/m2')
ax.grid(True, alpha=0.5)
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
df_3 = df_2[df_2['price'] > 2500000].groupby(['datetime', 'price', 'postal_code', 'year built']).size().reset_index(name='count')
df_4 = df_3[df_3['count'] > 1]

# %%
merged_data_2 = pd.merge(df_2, df_4, on=['datetime', 'price'], how='left', indicator=False)
merged_data_2 = merged_data_2.fillna(1)

df_5 = merged_data_2[merged_data_2['count'] == 1]
df_5.drop('postal_code_y', axis=1, inplace=True)
df_5.drop('year built_y', axis=1, inplace=True)
# Out:
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/1631703866.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_5.drop('postal_code_y', axis=1, inplace=True)
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/1631703866.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_5.drop('year built_y', axis=1, inplace=True)

# %%
df_5.drop('count', axis=1, inplace=True)
# Out:
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/1396983221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_5.drop('count', axis=1, inplace=True)

# %%
df_5.rename(columns={'year built_x': 'year built'}, inplace=True)
df_5.rename(columns={'postal_code_x': 'postal_code'}, inplace=True)
# Out:
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/2189968032.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_5.rename(columns={'year built_x': 'year built'}, inplace=True)
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/2189968032.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_5.rename(columns={'postal_code_x': 'postal_code'}, inplace=True)

# %%
sorted_2=df_5.sort_values(by='price', ascending=True)
df_5=df_5[df_5['price'] < 65531258]

# %% [markdown]
# The Final scatterplot without outliers for apartment prices

# %%
plt.figure(figsize=(10, 6))
ax = plt.gca()
plt.scatter(df_5['datetime'], df_5['kr/m2'], marker='o', alpha=0.7)
plt.title('Apartment Prices over Time')
plt.ylabel('kr/m2')
ax.grid(True, alpha=0.5)
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
#final plot with apartment prices
plt.figure(figsize=(10, 6))
ax = plt.gca()
plt.scatter(df_5['datetime'], df_5['price'], marker='o', alpha=0.7)
plt.title('Apartment Prices over Time')
plt.ylabel('kr.')
ax.grid(True, alpha=0.5)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Merging process

# %%
def construct_link(table_id, variables):
    base = f'https://api.statbank.dk/v1/data/{table_id}/JSONSTAT?lang=en'
    
    for var in variables:
        base += f'&{var}'

    return base 

construct_link('MPK3', ['Tid=*', 'Type=5500602011'])
#API FOR loan interest rate 
url = construct_link('MPK3', ['Tid=*', 'Type=5500602011'])

def create_data(url):
    response = requests.get(url).json()
    values = response['dataset']['value']
    years = response['dataset']['dimension']['Tid']['category']['index']
    data = dict(zip(years, values))
    return data

Interest_rate = create_data(url)

interest_rate_df = pd.DataFrame(Interest_rate.items(), columns=['Year', 'Loan interest rate']).dropna()

interest_rate_df['datetime'] = pd.to_datetime(interest_rate_df['Year'], format = '%YM%m')
interest_rate_df['year']= interest_rate_df['datetime'].dt.year
interest_rate_df['quarter']=interest_rate_df['datetime'].dt.quarter
interest_rate_df['year + quarter'] = interest_rate_df['year'].astype(str) + 'K' + interest_rate_df['quarter'].astype(str)
interest_rate_df.set_index('year + quarter', inplace=True)

interest_rate_df.drop('Year', axis=1, inplace=True)
interest_rate_df.drop('year', axis=1, inplace=True)
interest_rate_df.drop('quarter', axis=1, inplace=True)
interest_rate_df.drop('datetime', axis=1, inplace=True)

# %%
interest_rate_df
# Out:
#                 Loan interest rate
# year + quarter
# 1988K1                        0.00
# 1988K1                        0.00
# 1988K1                        0.00
# 1988K2                        0.00
# 1988K2                        0.00
# ...                            ...
# 2023K1                        2.75
# 2023K2                        2.75
# 2023K2                        3.00
# 2023K2                        3.25
# 2023K3                        3.50
#
# [182 rows x 1 columns]

# %%
interest_rate_df = interest_rate_df.groupby('year + quarter')['Loan interest rate'].mean().reset_index()

# %%
interest_rate_df.set_index('year + quarter', inplace=True)

# %%
df_5.set_index('year + quarter', inplace=True)

# %%
df_5
# Out:
#                    price  rooms  year built  \
# year + quarter
# 2023K3           2650000      1        1975
# 2023K3           1153000      1        1962
# 2023K3           1175000      2        1943
# 2023K3           3451000      4        2007
# 2023K3           5550000      3        2021
# ...                  ...    ...         ...
# 2017K1           1600000      4        1972
# 2017K1           3275000      4        2000
# 2017K1           1458000      2        1975
# 2017K1           2600000      3        1932
# 2017K1          23000000      3        1881
#
#                                                         address        date  \
# year + quarter
# 2023K3                   Søndre Fasanvej 94C, st. 49 2500 Valby  02-08-2023
# 2023K3                        Herlev Bygade 2, 1. 4 2730 Herlev  02-08-2023
# 2023K3          Christoffers Alle 70, st. 2 2800 Kongens Lyngby  02-08-2023
# 2023K3                  Gyngemose Parkvej 12, 2. tv 2860 Søborg  02-08-2023
# 2023K3                Strandlodsvej 23G, 7. th 2300 København S  02-08-2023
# ...                                                         ...         ...
# 2017K1                          Saksen C 4, st. 4 2630 Taastrup  04-01-2017
# 2017K1                            Engvej 40, st. tv 2791 Dragør  04-01-2017
# 2017K1                   Hamletsgade 4, 4. 198 2200 København N  04-01-2017
# 2017K1                 Schubertsvej 6, st. tv 2450 København SV  04-01-2017
# 2017K1                     Vævergade 3, st. tv 2200 København N  04-01-2017
#
#                  kr/m2   m2   datetime postal_code
# year + quarter
# 2023K3           39552   67 2023-08-02        2500
# 2023K3           23531   49 2023-08-02        2730
# 2023K3           27976   42 2023-08-02        2800
# 2023K3           35577   97 2023-08-02        2860
# 2023K3           56061   99 2023-08-02        2300
# ...                ...  ...        ...         ...
# 2017K1           13793  116 2017-01-04        2630
# 2017K1           31190  105 2017-01-04        2791
# 2017K1           25138   58 2017-01-04        2200
# 2017K1           35135   74 2017-01-04        2450
# 2017K1          319444   72 2017-01-04        2200
#
# [55313 rows x 9 columns]

# %%
df_6=df_5.join(interest_rate_df)

# %%
#API FOR consumer price index 
url = construct_link('PRIS111', ['Tid=*', 'VAREGR=000000', 'Enhed=200'])
def create_data(url):
    response = requests.get(url).json()
    values = response['dataset']['value']
    years = response['dataset']['dimension']['Tid']['category']['index']
    data = dict(zip(years, values))
    return data

Inflation = create_data(url)
Inflation_df = pd.DataFrame(Inflation.items(), columns=['Year', 'Inflation']).dropna()

Inflation_df['datetime'] = pd.to_datetime(Inflation_df['Year'], format = '%YM%m')
#Inflation_df['month'] = Inflation_df['datetime'].dt.month
Inflation_df['year']= Inflation_df['datetime'].dt.year
Inflation_df['quarter']=Inflation_df['datetime'].dt.quarter

Inflation_df['year + quarter'] = Inflation_df['year'].astype(str) + 'K' + Inflation_df['quarter'].astype(str)
# Inflation_df['year + month'] = Inflation_df['year'].astype(str) + Inflation_df['month'].astype(str)

Inflation_df.drop('datetime', axis=1, inplace=True)
#Inflation_df.drop('month', axis=1, inplace=True)
Inflation_df.drop('Year', axis=1, inplace=True)
Inflation_df.drop('quarter', axis=1, inplace=True)
Inflation_df.drop('year', axis=1, inplace=True)

Inflation_df = Inflation_df.groupby('year + quarter')['Inflation'].mean().reset_index()
Inflation_df.set_index('year + quarter', inplace=True)

# %%
df_7=df_6.join(Inflation_df)

# %%
df_7
# Out:
#                    price  rooms  year built  \
# year + quarter
# 2017K1           1775000      3        1966
# 2017K1           1440000      2        1962
# 2017K1           4495000      5        1885
# 2017K1           1800000      4        1912
# 2017K1           1375000      3        1963
# ...                  ...    ...         ...
# 2023K3          16449501      4        2023
# 2023K3            800000      4        1918
# 2023K3           2700000      2        1968
# 2023K3           1350000      2        1963
# 2023K3           7400000      4        1913
#
#                                                           address        date  \
# year + quarter
# 2017K1          Vejlegårdsparken 40, st. 7 2665 Vallensbæk Strand  31-03-2017
# 2017K1                        Rødovre Parkvej 281, 1 2610 Rødovre  30-03-2017
# 2017K1                      Kroghsgade 5, st. th 2100 København Ø  30-03-2017
# 2017K1                       Jagtvej 187, st. tv 2100 København Ø  30-03-2017
# 2017K1                      Brinchs Have 13, st. tv 2630 Taastrup  30-03-2017
# ...                                                           ...         ...
# 2023K3                         Papirøen 51, 6. 1 1436 København K  02-07-2023
# 2023K3                   Hollænderdybet 2, 2. th 2300 København S  02-07-2023
# 2023K3                   Holmbladsgade 94, 2. 26 2300 København S  01-07-2023
# 2023K3                      Taastrup Have 13, 2. tv 2630 Taastrup  01-07-2023
# 2023K3                         Ermelundsvej 116A, 1 2820 Gentofte  01-07-2023
#
#                  kr/m2   m2   datetime postal_code  Loan interest rate  \
# year + quarter
# 2017K1           20640   86 2017-03-31        2665                0.05
# 2017K1           23607   61 2017-03-30        2610                0.05
# 2017K1           40864  110 2017-03-30        2100                0.05
# 2017K1           18367   98 2017-03-30        2100                0.05
# 2017K1           19643   70 2017-03-30        2630                0.05
# ...                ...  ...        ...         ...                 ...
# 2023K3          132657  124 2023-07-02        1436                3.50
# 2023K3            8511   94 2023-07-02        2300                3.50
# 2023K3           36986   73 2023-07-01        2300                3.50
# 2023K3           22881   59 2023-07-01        2630                3.50
# 2023K3           47134  157 2023-07-01        2820                3.50
#
#                 Inflation
# year + quarter
# 2017K1                0.3
# 2017K1                0.3
# 2017K1                0.3
# 2017K1                0.3
# 2017K1                0.3
# ...                   ...
# 2023K3                1.8
# 2023K3                1.8
# 2023K3                1.8
# 2023K3                1.8
# 2023K3                1.8
#
# [55313 rows x 11 columns]

# %%
#API for salary
url = construct_link('SBLON1', ['Tid=*', 'BRANCHE07=*', 'VARIA1=100', 'SEKTOR=1000'])
def create_data(url):
    response = requests.get(url).json()
    values = response['dataset']['value']
    years = response['dataset']['dimension']['Tid']['category']['index']
    data = dict(zip(years, values))
    return data

salary_df = create_data(url)

salary_df = pd.DataFrame(salary_df.items(), columns=['year + quarter', 'Salary']).dropna()
salary_df.set_index('year + quarter', inplace=True)

# %%
df_8=df_7.join(salary_df)

# %%
#API for GDP 
url = construct_link('NKN1', ['Tid=*', 'S%C3%86SON=*', 'PRISENHED=LKV_M', 'TRANSAKT=B1GQK'])

def create_data(url):
    response = requests.get(url).json()
    values = response['dataset']['value']
    years = response['dataset']['dimension']['Tid']['category']['index']
    data = dict(zip(years, values))
    return data

gdp= create_data(url)
gdp_df = pd.DataFrame(gdp.items(), columns=['year + quarter', 'GDP']).dropna()
gdp_df.set_index('year + quarter', inplace=True)

# %%
df_9=df_8.join(gdp_df)

# %%
df_9
# Out:
#                    price  rooms  year built  \
# year + quarter
# 2017K1           1775000      3        1966
# 2017K1           1440000      2        1962
# 2017K1           4495000      5        1885
# 2017K1           1800000      4        1912
# 2017K1           1375000      3        1963
# ...                  ...    ...         ...
# 2023K3          16449501      4        2023
# 2023K3            800000      4        1918
# 2023K3           2700000      2        1968
# 2023K3           1350000      2        1963
# 2023K3           7400000      4        1913
#
#                                                           address        date  \
# year + quarter
# 2017K1          Vejlegårdsparken 40, st. 7 2665 Vallensbæk Strand  31-03-2017
# 2017K1                        Rødovre Parkvej 281, 1 2610 Rødovre  30-03-2017
# 2017K1                      Kroghsgade 5, st. th 2100 København Ø  30-03-2017
# 2017K1                       Jagtvej 187, st. tv 2100 København Ø  30-03-2017
# 2017K1                      Brinchs Have 13, st. tv 2630 Taastrup  30-03-2017
# ...                                                           ...         ...
# 2023K3                         Papirøen 51, 6. 1 1436 København K  02-07-2023
# 2023K3                   Hollænderdybet 2, 2. th 2300 København S  02-07-2023
# 2023K3                   Holmbladsgade 94, 2. 26 2300 København S  01-07-2023
# 2023K3                      Taastrup Have 13, 2. tv 2630 Taastrup  01-07-2023
# 2023K3                         Ermelundsvej 116A, 1 2820 Gentofte  01-07-2023
#
#                  kr/m2   m2   datetime postal_code  Loan interest rate  \
# year + quarter
# 2017K1           20640   86 2017-03-31        2665                0.05
# 2017K1           23607   61 2017-03-30        2610                0.05
# 2017K1           40864  110 2017-03-30        2100                0.05
# 2017K1           18367   98 2017-03-30        2100                0.05
# 2017K1           19643   70 2017-03-30        2630                0.05
# ...                ...  ...        ...         ...                 ...
# 2023K3          132657  124 2023-07-02        1436                3.50
# 2023K3            8511   94 2023-07-02        2300                3.50
# 2023K3           36986   73 2023-07-01        2300                3.50
# 2023K3           22881   59 2023-07-01        2630                3.50
# 2023K3           47134  157 2023-07-01        2820                3.50
#
#                 Inflation  Salary    GDP
# year + quarter
# 2017K1                0.3   100.8  495.4
# 2017K1                0.3   100.8  495.4
# 2017K1                0.3   100.8  495.4
# 2017K1                0.3   100.8  495.4
# 2017K1                0.3   100.8  495.4
# ...                   ...     ...    ...
# 2023K3                1.8     NaN    NaN
# 2023K3                1.8     NaN    NaN
# 2023K3                1.8     NaN    NaN
# 2023K3                1.8     NaN    NaN
# 2023K3                1.8     NaN    NaN
#
# [55313 rows x 13 columns]

# %%
df_9=df_9.dropna()
df_9.drop('date', axis=1, inplace=True) 
#set everything as floats 
df_9['postal_code']=df_9['postal_code'].astype(float)
df_9['rooms']=df_9['rooms'].astype(float)
df_9['price']=df_9['price'].astype(float)
df_9['year built']=df_9['year built'].astype(float)
df_9['kr/m2']=df_9['kr/m2'].astype(float)
df_9['m2']=df_9['m2'].astype(float)
# Out:
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/4254065937.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_9.drop('date', axis=1, inplace=True)
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/4254065937.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_9['postal_code']=df_9['postal_code'].astype(float)
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/4254065937.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_9['rooms']=df_9['rooms'].astype(float)
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/4254065937.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_9['price']=df_9['price'].astype(float)
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/4254065937.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_9['year built']=df_9['year built'].astype(float)
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/4254065937.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_9['kr/m2']=df_9['kr/m2'].astype(float)
# /var/folders/5k/v848_lfn4c7fkwyhsjyv_0b40000gn/T/ipykernel_61545/4254065937.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_9['m2']=df_9['m2'].astype(float)

# %%
df_9
# Out:
#                     price  rooms  year built  \
# year + quarter
# 2017K1          1775000.0    3.0      1966.0
# 2017K1          1440000.0    2.0      1962.0
# 2017K1          4495000.0    5.0      1885.0
# 2017K1          1800000.0    4.0      1912.0
# 2017K1          1375000.0    3.0      1963.0
# ...                   ...    ...         ...
# 2023K1          2700000.0    2.0      1990.0
# 2023K1          8900000.0    4.0      1904.0
# 2023K1          2995000.0    4.0      1946.0
# 2023K1          2580000.0    2.0      1902.0
# 2023K1          6799000.0    1.0         0.0
#
#                                                           address    kr/m2  \
# year + quarter
# 2017K1          Vejlegårdsparken 40, st. 7 2665 Vallensbæk Strand  20640.0
# 2017K1                        Rødovre Parkvej 281, 1 2610 Rødovre  23607.0
# 2017K1                      Kroghsgade 5, st. th 2100 København Ø  40864.0
# 2017K1                       Jagtvej 187, st. tv 2100 København Ø  18367.0
# 2017K1                      Brinchs Have 13, st. tv 2630 Taastrup  19643.0
# ...                                                           ...      ...
# 2023K1                       Allersgade 2, 2. mf 2200 København N  38571.0
# 2023K1            Sankt Thomas Alle 9, 4. tv 1824 Frederiksberg C  86408.0
# 2023K1                    Smakkegårdsvej 169, 1. tv 2820 Gentofte  32912.0
# 2023K1                       Ægirsgade 37, 4. tv 2200 København N  51600.0
# 2023K1                      Dunkerquegade 23, 3. tv 2150 Nordhavn  73902.0
#
#                    m2   datetime  postal_code  Loan interest rate  Inflation  \
# year + quarter
# 2017K1           86.0 2017-03-31       2665.0                0.05   0.300000
# 2017K1           61.0 2017-03-30       2610.0                0.05   0.300000
# 2017K1          110.0 2017-03-30       2100.0                0.05   0.300000
# 2017K1           98.0 2017-03-30       2100.0                0.05   0.300000
# 2017K1           70.0 2017-03-30       2630.0                0.05   0.300000
# ...               ...        ...          ...                 ...        ...
# 2023K1           70.0 2023-01-01       2200.0                2.30   0.366667
# 2023K1          103.0 2023-01-01       1824.0                2.30   0.366667
# 2023K1           91.0 2023-01-01       2820.0                2.30   0.366667
# 2023K1           50.0 2023-01-01       2200.0                2.30   0.366667
# 2023K1           92.0 2023-01-01       2150.0                2.30   0.366667
#
#                 Salary    GDP
# year + quarter
# 2017K1           100.8  495.4
# 2017K1           100.8  495.4
# 2017K1           100.8  495.4
# 2017K1           100.8  495.4
# 2017K1           100.8  495.4
# ...                ...    ...
# 2023K1           115.3  558.0
# 2023K1           115.3  558.0
# 2023K1           115.3  558.0
# 2023K1           115.3  558.0
# 2023K1           115.3  558.0
#
# [53129 rows x 12 columns]

# %% [markdown]
# Webscraping from  'https://peters1.dk/postnummer/' to creat create categorization of postal_codes

# %%
url = 'https://peters1.dk/postnummer/'
response = requests.get(url)

# Parse data with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')
# Identify table to scrape by inspecting site
table_node = soup.find(id='myTable')
rows = table_node.find_all('tr')
data = []
columns = ['Postnr.', 'Bynavn', 'Gade']


for row in rows[1:]:  # Skip the first row (header)
    cols = row.find_all('td')
    row_data = [col.text.strip() for col in cols]
    data.append(row_data)

post_number = pd.DataFrame(data, columns=columns)
post_number.columns= ['postal_code', 'city_name', 'Gade'] 
post_number.drop('Gade', axis=1, inplace=True)

# %%
post_number['postal_code'] = post_number['postal_code'].astype(float)

# %%
post_number['category'] = post_number['city_name'].astype('category')

# %%
df_10= df_9.merge(post_number, on='postal_code', how='left')

# %%
df_11=df_10.dropna()

# %%
#we drop duplicates to get rid of the last double observations 
df_11=df_11.drop_duplicates()

# %%
df_11.reset_index(drop=True)
# Out:
#            price  rooms  year built  \
# 0      1775000.0    3.0      1966.0
# 1      1440000.0    2.0      1962.0
# 2      4495000.0    5.0      1885.0
# 3      1800000.0    4.0      1912.0
# 4      1375000.0    3.0      1963.0
# ...          ...    ...         ...
# 53012  2700000.0    2.0      1990.0
# 53013  8900000.0    4.0      1904.0
# 53014  2995000.0    4.0      1946.0
# 53015  2580000.0    2.0      1902.0
# 53016  6799000.0    1.0         0.0
#
#                                                  address    kr/m2     m2  \
# 0      Vejlegårdsparken 40, st. 7 2665 Vallensbæk Strand  20640.0   86.0
# 1                    Rødovre Parkvej 281, 1 2610 Rødovre  23607.0   61.0
# 2                  Kroghsgade 5, st. th 2100 København Ø  40864.0  110.0
# 3                   Jagtvej 187, st. tv 2100 København Ø  18367.0   98.0
# 4                  Brinchs Have 13, st. tv 2630 Taastrup  19643.0   70.0
# ...                                                  ...      ...    ...
# 53012               Allersgade 2, 2. mf 2200 København N  38571.0   70.0
# 53013    Sankt Thomas Alle 9, 4. tv 1824 Frederiksberg C  86408.0  103.0
# 53014            Smakkegårdsvej 169, 1. tv 2820 Gentofte  32912.0   91.0
# 53015               Ægirsgade 37, 4. tv 2200 København N  51600.0   50.0
# 53016              Dunkerquegade 23, 3. tv 2150 Nordhavn  73902.0   92.0
#
#         datetime  postal_code  Loan interest rate  Inflation  Salary    GDP  \
# 0     2017-03-31       2665.0                0.05   0.300000   100.8  495.4
# 1     2017-03-30       2610.0                0.05   0.300000   100.8  495.4
# 2     2017-03-30       2100.0                0.05   0.300000   100.8  495.4
# 3     2017-03-30       2100.0                0.05   0.300000   100.8  495.4
# 4     2017-03-30       2630.0                0.05   0.300000   100.8  495.4
# ...          ...          ...                 ...        ...     ...    ...
# 53012 2023-01-01       2200.0                2.30   0.366667   115.3  558.0
# 53013 2023-01-01       1824.0                2.30   0.366667   115.3  558.0
# 53014 2023-01-01       2820.0                2.30   0.366667   115.3  558.0
# 53015 2023-01-01       2200.0                2.30   0.366667   115.3  558.0
# 53016 2023-01-01       2150.0                2.30   0.366667   115.3  558.0
#
#                city_name           category
# 0      Vallensbæk Strand  Vallensbæk Strand
# 1                Rødovre            Rødovre
# 2            København Ø        København Ø
# 3            København Ø        København Ø
# 4               Taastrup           Taastrup
# ...                  ...                ...
# 53012        København N        København N
# 53013    Frederiksberg C    Frederiksberg C
# 53014           Gentofte           Gentofte
# 53015        København N        København N
# 53016           Nordhavn           Nordhavn
#
# [53017 rows x 14 columns]

# %%
sns.displot(df_11['price'])

# %%
#convert to log 
sns.displot(np.log(df_11['price']))
plt.show()

# %%
sns.set(style="whitegrid")
sns.set_palette("Set2")

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

scatter_plot = sns.scatterplot(data=df_11, x='rooms', y='price', ax=axes[0, 0])
scatter_plot.set(title='Rooms vs. Aparment Price')
scatter_plot.set_xlabel('Rooms')
scatter_plot.set_ylabel('Price')
sns.regplot(data=df_11, x='rooms', y='price', ax=axes[0, 0], scatter=False, color='blue')

scatter_plot = sns.scatterplot(data=df_11, x='year built', y='price', ax=axes[0, 1])
scatter_plot.set(title='Year built vs. Aparment Price')
scatter_plot.set_xlabel('Year built')
scatter_plot.set_ylabel('Price')
sns.regplot(data=df_11, x='year built', y='price', ax=axes[0, 1], scatter=False, color='blue')


scatter_plot = sns.scatterplot(data=df_11, x='postal_code', y='price', ax=axes[0, 2])
scatter_plot.set(title='Postal Code vs. Aparment Price')
scatter_plot.set_xlabel('Postal code')
scatter_plot.set_ylabel('Price')
sns.regplot(data=df_11, x='postal_code', y='price', ax=axes[0, 2], scatter=False, color='blue')


plt.tight_layout()
plt.show()
plt.savefig('scatter_plots.png', dpi=300)

# %% [markdown]
# Since there that many of the observations for year build is year, we further have to clean the data

# %%
df_11['year built'] = df_11['year built'].replace(0, df_11[df_11['year built'] > 0]['year built'].mean())

# %%
sns.set(style="whitegrid")
sns.set_palette("Set2")

# Create a figure with 2 rows and 4 columns of subplots
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(15, 10))

# Create scatter plots with lines and customize each subplot
scatter_plot = sns.scatterplot(data=df_11, x='GDP', y='price', ax=axes[0, 0])
scatter_plot.set(title='GDP vs. Aparment Price')
scatter_plot.set_xlabel('GDP')
scatter_plot.set_ylabel('Price')
sns.regplot(data=df_11, x='GDP', y='price', ax=axes[0, 0], scatter=False, color='blue')

scatter_plot = sns.scatterplot(data=df_11, x='Salary', y='price', ax=axes[0, 1])
scatter_plot.set(title='Salary vs. Aparment Price')
scatter_plot.set_xlabel('GDP')
scatter_plot.set_ylabel('Price')
sns.regplot(data=df_11, x='Salary', y='price', ax=axes[0, 1], scatter=False, color='blue')

scatter_plot = sns.scatterplot(data=df_11, x='Inflation', y='price', ax=axes[0, 2])
scatter_plot.set(title='Inflation vs. Aparment Price')
scatter_plot.set_xlabel('Inflation')
scatter_plot.set_ylabel('Price')
sns.regplot(data=df_11, x='Inflation', y='price', ax=axes[0, 2], scatter=False, color='blue')


scatter_plot = sns.scatterplot(data=df_11, x='Loan interest rate', y='price', ax=axes[1, 0])
scatter_plot.set(title='Loan interest rate vs. Aparment Price')
scatter_plot.set_xlabel('Loan interest rate')
scatter_plot.set_ylabel('Price')
sns.regplot(data=df_11, x='Loan interest rate', y='price', ax=axes[1, 0], scatter=False, color='blue')

scatter_plot = sns.scatterplot(data=df_11, x='rooms', y='price', ax=axes[1, 1])
scatter_plot.set(title='Rooms vs. Aparment Price')
scatter_plot.set_xlabel('Rooms')
scatter_plot.set_ylabel('Price')
sns.regplot(data=df_11, x='rooms', y='price', ax=axes[1, 1], scatter=False, color='blue')

scatter_plot = sns.scatterplot(data=df_11, x='year built', y='price', ax=axes[1, 2])
scatter_plot.set(title='Year built vs. Aparment Price')
scatter_plot.set_xlabel('Year built')
scatter_plot.set_ylabel('Price')
sns.regplot(data=df_11, x='year built', y='price', ax=axes[1, 2], scatter=False, color='blue')


scatter_plot = sns.scatterplot(data=df_11, x='postal_code', y='price', ax=axes[0, 3])
scatter_plot.set(title='Postal Code vs. Aparment Price')
scatter_plot.set_xlabel('Postal code')
scatter_plot.set_ylabel('Price')
sns.regplot(data=df_11, x='postal_code', y='price', ax=axes[0, 3], scatter=False, color='blue')

axes[1,3].axis('off')

# Adjust spacing between subplots
plt.tight_layout()

# Show the combined plot
plt.show()
plt.savefig('scatter_plots.png', dpi=300)

# %%
#Correlation map 
plt.figure(figsize = (20, 12))
sns.heatmap(df_11.corr(), annot= True, cmap= 'coolwarm', fmt= '.2f', vmin= -1, vmax= 1)
plt.title('Correlation heatmap', fontsize=20)
plt.show()
plt.savefig('heatmap', dpi=300)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df_12= df_11

# %%
df_12.sort_values(by='postal_code', ascending=True)
# Out:
#             price  rooms  year built                            address  \
# 57918   7500000.0    2.0      1900.0  Nyhavn 31E, 1. 4 1051 København K
# 30411  13250000.0    2.0      1780.0    Nyhavn 12C, st 1051 København K
# 65152  19500000.0    3.0      1683.0      Nyhavn 29, 1 1051 København K
# 47765  14800000.0    5.0      1770.0      Nyhavn 16, 3 1051 København K
# 61444  19500000.0    7.0      1880.0  Nyhavn 38, 5. tv 1051 København K
# ...           ...    ...         ...                                ...
# 21219   1320000.0    3.0      1971.0     Langelunden 5, 2. tv 2990 Nivå
# 65380   1895000.0    4.0      1971.0     Langelunden 1, 2. th 2990 Nivå
# 42339   1275000.0    3.0      1971.0    Langelunden 8, st. th 2990 Nivå
# 57604   1845000.0    3.0      1971.0     Langelunden 3, 3. tv 2990 Nivå
# 63390   1065000.0    1.0      1971.0   Langelunden 15, st. mf 2990 Nivå
#
#          kr/m2     m2   datetime  postal_code  Loan interest rate  \
# 57918  74257.0  101.0 2021-10-29       1051.0           -0.450000
# 30411  70106.0  189.0 2020-09-20       1051.0            0.050000
# 65152  98485.0  198.0 2022-09-21       1051.0            0.300000
# 47765  70476.0  185.0 2021-05-19       1051.0           -0.350000
# 61444  65878.0  296.0 2022-01-25       1051.0           -0.450000
# ...        ...    ...        ...          ...                 ...
# 21219  15349.0   86.0 2019-08-22       2990.0            0.050000
# 65380  18578.0  102.0 2022-09-11       2990.0            0.300000
# 42339  13564.0   94.0 2021-02-14       2990.0           -0.083333
# 57604  21453.0   86.0 2021-11-07       2990.0           -0.450000
# 63390  23152.0   46.0 2022-05-22       2990.0           -0.450000
#
#           Inflation  Salary    GDP    city_name     category
# 57918  2.333333e-01   111.0  587.5  København K  København K
# 30411  1.000000e-01   108.1  515.4  København K  København K
# 65152  8.000000e-01   113.0  561.8  København K  København K
# 47765  2.333333e-01   110.8  555.8  København K  København K
# 61444  1.000000e+00   111.5  547.5  København K  København K
# ...             ...     ...    ...          ...          ...
# 21219 -1.850372e-17   106.2  526.0         Nivå         Nivå
# 65380  8.000000e-01   113.0  561.8         Nivå         Nivå
# 42339  3.000000e-01   109.0  520.1         Nivå         Nivå
# 57604  2.333333e-01   111.0  587.5         Nivå         Nivå
# 63390  1.100000e+00   113.6  572.5         Nivå         Nivå
#
# [53017 rows x 14 columns]

# %%
df_12['category']=label_encoder.fit_transform(df_12['category'])

# %%
df_12
# Out:
#            price  rooms   year built  \
# 0      1775000.0    3.0  1966.000000
# 1      1440000.0    2.0  1962.000000
# 2      4495000.0    5.0  1885.000000
# 3      1800000.0    4.0  1912.000000
# 4      1375000.0    3.0  1963.000000
# ...          ...    ...          ...
# 70749  2700000.0    2.0  1990.000000
# 70750  8900000.0    4.0  1904.000000
# 70751  2995000.0    4.0  1946.000000
# 70752  2580000.0    2.0  1902.000000
# 70753  6799000.0    1.0  1950.436911
#
#                                                  address    kr/m2     m2  \
# 0      Vejlegårdsparken 40, st. 7 2665 Vallensbæk Strand  20640.0   86.0
# 1                    Rødovre Parkvej 281, 1 2610 Rødovre  23607.0   61.0
# 2                  Kroghsgade 5, st. th 2100 København Ø  40864.0  110.0
# 3                   Jagtvej 187, st. tv 2100 København Ø  18367.0   98.0
# 4                  Brinchs Have 13, st. tv 2630 Taastrup  19643.0   70.0
# ...                                                  ...      ...    ...
# 70749               Allersgade 2, 2. mf 2200 København N  38571.0   70.0
# 70750    Sankt Thomas Alle 9, 4. tv 1824 Frederiksberg C  86408.0  103.0
# 70751            Smakkegårdsvej 169, 1. tv 2820 Gentofte  32912.0   91.0
# 70752               Ægirsgade 37, 4. tv 2200 København N  51600.0   50.0
# 70753              Dunkerquegade 23, 3. tv 2150 Nordhavn  73902.0   92.0
#
#         datetime  postal_code  Loan interest rate  Inflation  Salary    GDP  \
# 0     2017-03-31       2665.0                0.05   0.300000   100.8  495.4
# 1     2017-03-30       2610.0                0.05   0.300000   100.8  495.4
# 2     2017-03-30       2100.0                0.05   0.300000   100.8  495.4
# 3     2017-03-30       2100.0                0.05   0.300000   100.8  495.4
# 4     2017-03-30       2630.0                0.05   0.300000   100.8  495.4
# ...          ...          ...                 ...        ...     ...    ...
# 70749 2023-01-01       2200.0                2.30   0.366667   115.3  558.0
# 70750 2023-01-01       1824.0                2.30   0.366667   115.3  558.0
# 70751 2023-01-01       2820.0                2.30   0.366667   115.3  558.0
# 70752 2023-01-01       2200.0                2.30   0.366667   115.3  558.0
# 70753 2023-01-01       2150.0                2.30   0.366667   115.3  558.0
#
#                city_name  category
# 0      Vallensbæk Strand        47
# 1                Rødovre        38
# 2            København Ø        32
# 3            København Ø        32
# 4               Taastrup        44
# ...                  ...       ...
# 70749        København N        27
# 70750    Frederiksberg C        10
# 70751           Gentofte        11
# 70752        København N        27
# 70753           Nordhavn        35
#
# [53017 rows x 14 columns]

# %%
df_13=df_12.drop(columns=['city_name'])
df_14=df_13.drop(columns=['address'])

# %%
df_14
# Out:
#            price  rooms   year built    kr/m2     m2   datetime  postal_code  \
# 0      1775000.0    3.0  1966.000000  20640.0   86.0 2017-03-31       2665.0
# 1      1440000.0    2.0  1962.000000  23607.0   61.0 2017-03-30       2610.0
# 2      4495000.0    5.0  1885.000000  40864.0  110.0 2017-03-30       2100.0
# 3      1800000.0    4.0  1912.000000  18367.0   98.0 2017-03-30       2100.0
# 4      1375000.0    3.0  1963.000000  19643.0   70.0 2017-03-30       2630.0
# ...          ...    ...          ...      ...    ...        ...          ...
# 70749  2700000.0    2.0  1990.000000  38571.0   70.0 2023-01-01       2200.0
# 70750  8900000.0    4.0  1904.000000  86408.0  103.0 2023-01-01       1824.0
# 70751  2995000.0    4.0  1946.000000  32912.0   91.0 2023-01-01       2820.0
# 70752  2580000.0    2.0  1902.000000  51600.0   50.0 2023-01-01       2200.0
# 70753  6799000.0    1.0  1950.436911  73902.0   92.0 2023-01-01       2150.0
#
#        Loan interest rate  Inflation  Salary    GDP  category
# 0                    0.05   0.300000   100.8  495.4        47
# 1                    0.05   0.300000   100.8  495.4        38
# 2                    0.05   0.300000   100.8  495.4        32
# 3                    0.05   0.300000   100.8  495.4        32
# 4                    0.05   0.300000   100.8  495.4        44
# ...                   ...        ...     ...    ...       ...
# 70749                2.30   0.366667   115.3  558.0        27
# 70750                2.30   0.366667   115.3  558.0        10
# 70751                2.30   0.366667   115.3  558.0        11
# 70752                2.30   0.366667   115.3  558.0        27
# 70753                2.30   0.366667   115.3  558.0        35
#
# [53017 rows x 12 columns]

# %%
df_14.to_csv('output.csv', index=False, float_format='%.1f')

# %%
summary_stats = df_14.describe().T
summary_stats
# Out:
#                       count          mean           std           min  \
# price               53017.0  3.629690e+06  2.574290e+06  10000.000000
# rooms               53017.0  2.831356e+00  1.080902e+00      1.000000
# year built          53017.0  1.950437e+03  4.654200e+01   1623.000000
# kr/m2               53017.0  4.203063e+04  1.809581e+04     84.000000
# m2                  53017.0  8.332148e+01  3.414804e+01     11.000000
# postal_code         53017.0  2.337781e+03  4.179237e+02   1051.000000
# Loan interest rate  53017.0  6.292510e-02  5.585358e-01     -0.450000
# Inflation           53017.0  2.206431e-01  3.160290e-01     -0.166667
# Salary              53017.0  1.080233e+02  3.794621e+00    100.800000
# GDP                 53017.0  5.356052e+02  2.501607e+01    495.400000
# category            53017.0  2.661695e+01  1.211918e+01      0.000000
#
#                              25%         50%         75%         max
# price               2.045000e+06  2950000.00  4495000.00  48092040.0
# rooms               2.000000e+00        3.00        3.00        15.0
# year built          1.928000e+03     1950.00     1977.00      2023.0
# kr/m2               3.154800e+04    40323.00    50505.00   1127586.0
# m2                  5.900000e+01       76.00      100.00       857.0
# postal_code         2.100000e+03     2300.00     2670.00      2990.0
# Loan interest rate -8.333333e-02        0.05        0.05         2.3
# Inflation          -9.251859e-18        0.20        0.30         1.1
# Salary              1.049000e+02      108.10      110.80       115.3
# GDP                 5.154000e+02      528.90      548.50       590.4
# category            1.800000e+01       29.00       32.00        50.0

# %%
#final plot with apartment prices
plt.figure(figsize=(10, 6))
ax = plt.gca()
plt.scatter(df_14['datetime'], df_14['kr/m2'], marker='o', alpha=0.7)
plt.ylabel('kr/m2')
ax.grid(True, alpha=0.5)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#final plot with apartment prices
plt.figure(figsize=(10, 6))
ax = plt.gca()
plt.scatter(df_14['datetime'], df_14['price'], marker='o', alpha=0.7)
plt.ylabel('kr.')
ax.grid(True, alpha=0.5)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
